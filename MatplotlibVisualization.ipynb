# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## matplotlib library

# %%
import matplotlib.pylab as plt #Typically matplotlib.pylab is imported as plt (shortened name)
# %matplotlib inline 
#The above line is necessary so that figures are displayed on the webpage instead of separate pop-ups

# %% [markdown]
# ## Scatter Plot
# https://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.scatter

# %%
import pandas as pd
#data = pd.read_csv('CarsData.csv') # Import cars data
data = pd.read_csv('all_price_data.csv') 
print(data.head()) #Check first 5 rows of the data to make sure everythin is alright
# Out:
#    Unnamed: 0       BN    Drug_Form_Strength NPT_DESC drugname  price_date  \
# 0           0  ABILIFY  ABILIFY 10 MG TABLET    WAAMP  ABILIFY  01/01/2019
# 1           1  ABILIFY  ABILIFY 10 MG TABLET      FUL  ABILIFY  01/01/2019
# 2           2  ABILIFY  ABILIFY 10 MG TABLET   NADACB  ABILIFY  12/19/2018
# 3           3  ABILIFY  ABILIFY 10 MG TABLET   NADACG  ABILIFY  12/19/2018
# 4           4  ABILIFY  ABILIFY 10 MG TABLET    WAAMP  ABILIFY  12/01/2018
#
#       price
# 0   1.84898
# 1   3.23571
# 2  28.61513
# 3   0.34431
# 4   2.07831

# %%
# Basic pie chart
plt.scatter(data.horsepower, data.mpg)
plt.xlabel('Horsepower')
plt.ylabel('Miles Per Gallon')
plt.show()

# %% [markdown]
# ## Pie Chart
#
# https://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.pie

# %%
# Data to plot
labels = ['Python', 'C++', 'Ruby', 'Java']
sizes = [215, 130, 245, 210]

# %%
# Basic pie chart
plt.pie(sizes, labels=labels)
plt.show()

# %%
# .pie() function has many parameters see: https://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.pie
# Here is a more elaborate example with other parameters

colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue'] #pick some four colors
explode = (0.2, 0, 0, 0)  # explode 1st slice
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal') #so that it is a circle 
plt.show()

# %% [markdown]
# ## Histogram
# https://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.hist

# %%
import pandas as pd
data = pd.read_csv('CarsData.csv') # Import cars data
print data.head() #Check first 5 rows of the data to make sure everythin is alright
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0         130    3504          12.0
# 1  15.0          8         350.0         165    3693          11.5
# 2  18.0          8         318.0         150    3436          11.0
# 3  16.0          8         304.0         150    3433          12.0
# 4  17.0          8         302.0         140    3449          10.5
#
#    model_year   origin                   car_name      maker
# 0          70  America  chevrolet chevelle malibu  chevrolet
# 1          70  America          buick skylark 320      buick
# 2          70  America         plymouth satellite   plymouth
# 3          70  America              amc rebel sst        amc
# 4          70  America                ford torino       ford

# %%
# Basic histogram of the mpg
plt.hist(data.mpg)
plt.xlabel('Miles Per Galon')
plt.ylabel('Count')
plt.show()

# %%
meansAmerica.index
# Out:
# Index([u'mpg', u'cylinders', u'displacement', u'horsepower', u'weight',
#        u'acceleration', u'model_year'],
#       dtype='object')

# %%
# A more extansive example of histograms by characteristic

meansAmerica = data[data.origin=="America"].mean() 
meansAsia = data[data.origin=="Asia"].mean() 
 
# create plot
fig, ax = plt.subplots()
bar_width = 0.35
opacity = 0.8
locAmerica = range(len(meansAmerica))
locAsia=[x+bar_width for x in locAmerica]
locLabel=[x+bar_width/2 for x in locAmerica]

 
rects1 = plt.bar(locAmerica, meansAmerica, bar_width,alpha=opacity,color='b',label='America')
rects2 = plt.bar(locAsia, meansAsia, bar_width,alpha=opacity,color='g',label='Asia')
 
plt.xlabel('Attribute')
plt.ylabel('Average Length')
plt.title('Comparison between Setosa and Virginica')
plt.xticks(locLabel, meansAmerica.index,rotation=40)
plt.legend()
plt.tight_layout()
plt.show()
